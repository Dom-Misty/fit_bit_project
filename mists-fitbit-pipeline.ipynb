# %% [markdown]
# # Analyzing Collected Fitbit Data

# %% [markdown]
# ## Table of Contents
# I. Project Plan
# - Goals
# - Findings
#
# II. Data Dictionary
#
# III. Acquire
#
# IV. Prepare
#
# V. Feature Engineering
#
# VI. Explore
# - Investigate BMR
# - Determine Height
# - Trends by Day
#
# VII. Model
#
# VIII. Summary

# %% [markdown]
# ## I. Project Plan

# %% [markdown]
# Goals
# - Use timeseries analysis
# - Understand who/what the csv files represent
# - Predict the next two weeks
#
# Findings
# - person height and weight

# %% [markdown]
# ## II. Data Dictionary

# %% [markdown]
# | variable | description   | units  |
# |---|---|---|
# | cal_burned  | the number of calories burned  | number  |
# | activity_cals  |  the number of calories due to activity |  number |
# | steps  | the number of steps taken |  number |
# | distance  | the distance traveled  | miles  |
# | floors  | the distance traveled upwards  | 10 feet  |
# | mins_sedentary  | length of sedentary activity | mins   |
# | mins_light_activity  | length of light activity  | mins  |
# | mins_fair_activity  | length of fair activity  | mins  |
# | mins_very_active  | length of heavy activity  |  mins |
# | mins_total_activity  | lenth of total activity  |  mins |
# | day  | the day of the week  | n/a  |

# %%
# data manipulation
import pandas as pd
import numpy as np

from sklearn.model_selection import TimeSeriesSplit
from sklearn import metrics

import math
from datetime import datetime

# visualizations
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.api as sm

# py files for reproducibility 
import prepare
import explore
import split
import model

# ignore warnings
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ## III. Acquire

# %% [markdown]
# The thumbdrive contained multiple files of data containing food and activity logs. Upon inspection, it was determined that this single thumbdrive encompasses one person's logs, each log being about 30 days long. It was immediatly noted that food logs are rountinely not filled out. Therefore, only activity logs were utilized in this analysis. The activity logs were extracted and combined into one newly created csv file.
#
# The `acquire_data` function reads the csv file "activity_logs.csv" and exports it as a dataframe.

# %%
df = prepare.acquire_data()

# %% [markdown]
# ## IV. Prepare

# %%
df.info()
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 225 entries, 0 to 224
# Data columns (total 10 columns):
# Date                      225 non-null object
# Calories Burned           225 non-null object
# Steps                     225 non-null object
# Distance                  225 non-null float64
# Floors                    225 non-null int64
# Minutes Sedentary         225 non-null object
# Minutes Lightly Active    225 non-null int64
# Minutes Fairly Active     225 non-null int64
# Minutes Very Active       225 non-null int64
# Activity Calories         225 non-null object
# dtypes: float64(1), int64(4), object(5)
# memory usage: 17.7+ KB
#       Date Calories Burned  Steps  Distance  Floors Minutes Sedentary  \
# 0  4/26/18           2,635  2,931      1.38       2             1,347
# 1  4/27/18           3,649  9,971      4.70      19             1,158
# 2  4/28/18           3,379  3,521      1.66       2               702
# 3  4/29/18           2,851  1,639      0.77       0               891
# 4  4/30/18           2,825  1,323      0.62       0               880
#
#    Minutes Lightly Active  Minutes Fairly Active  Minutes Very Active  \
# 0                      93                      0                    0
# 1                     219                     46                   17
# 2                     155                     22                   11
# 3                     122                      0                    0
# 4                     104                      0                    0
#
#   Activity Calories
# 0               566
# 1             1,752
# 2             1,124
# 3               602
# 4               540

# %%
df.isnull().sum()
# Out:
# Date                      0
# Calories Burned           0
# Steps                     0
# Distance                  0
# Floors                    0
# Minutes Sedentary         0
# Minutes Lightly Active    0
# Minutes Fairly Active     0
# Minutes Very Active       0
# Activity Calories         0
# dtype: int64

# %% [markdown]
# > It is seen that there are no nulls to be addressed. Only minor clean-up should be needed.

# %% [markdown]
# In the `prep_fitbit_data` fuction, the following prep is down on the dataframe:
# - Rename columns with names that contain only lowercase and no spaces
# - Change the date to a datetime format, set as index, and sort the index
# - Remove commas from object columns
# - Change all columns to floats

# %%
df = prepare.prep_fitbit_data(df)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 225 entries, 2018-04-26 to 2018-12-06
# Data columns (total 9 columns):
# cal_burned             225 non-null float64
# steps                  225 non-null float64
# distance               225 non-null float64
# floors                 225 non-null float64
# mins_sedentary         225 non-null float64
# mins_light_activity    225 non-null float64
# mins_fair_activity     225 non-null float64
# mins_very_active       225 non-null float64
# activity_cals          225 non-null float64
# dtypes: float64(9)
# memory usage: 17.6 KB

# %%
df.describe()
# Out:
#         cal_burned         steps    distance      floors  mins_sedentary  \
# count   225.000000    225.000000  225.000000  225.000000      225.000000
# mean   3401.911111   8536.186667    4.046800   12.591111      809.520000
# std     632.426578   5255.746608    2.506253   25.844174      243.232639
# min     799.000000      0.000000    0.000000    0.000000       28.000000
# 25%    3069.000000   4714.000000    2.220000    2.000000      654.000000
# 50%    3385.000000   7806.000000    3.680000    7.000000      750.000000
# 75%    3765.000000  12380.000000    5.900000   13.000000      877.000000
# max    5199.000000  25512.000000   12.000000  195.000000     1440.000000
#
#        mins_light_activity  mins_fair_activity  mins_very_active  \
# count           225.000000          225.000000        225.000000
# mean            188.235556           14.920000         33.871111
# std              75.170001           15.363535         37.195986
# min               0.000000            0.000000          0.000000
# 25%             158.000000            3.000000          2.000000
# 50%             203.000000           11.000000         15.000000
# 75%             236.000000           21.000000         63.000000
# max             349.000000           78.000000        154.000000
#
#        activity_cals
# count     225.000000
# mean     1484.546667
# std       747.795790
# min         0.000000
# 25%      1062.000000
# 50%      1481.000000
# 75%      1962.000000
# max      3596.000000

# %% [markdown]
# ## V. Feature Engineering

# %% [markdown]
# Create new features that may provide additional insight.
# - Derived `mins_total_activity` column that adds up all the minutes of activity columns
# - Extracted the day of the week for each row

# %%
df = prepare.add_features(df)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 225 entries, 2018-04-26 to 2018-12-06
# Data columns (total 11 columns):
# cal_burned             225 non-null float64
# steps                  225 non-null float64
# distance               225 non-null float64
# floors                 225 non-null float64
# mins_sedentary         225 non-null float64
# mins_light_activity    225 non-null float64
# mins_fair_activity     225 non-null float64
# mins_very_active       225 non-null float64
# activity_cals          225 non-null float64
# mins_total_activity    225 non-null float64
# day                    225 non-null object
# dtypes: float64(10), object(1)
# memory usage: 21.1+ KB

# %% [markdown]
# ## VI. Explore

# %%
# sns.pairplot(df)
plt.show()

# %%
# plt.figure(figsize = (12,6))
# sns.heatmap(df.corr(),annot=True)
plt.show()

# %% [markdown]
# > It is seen that many values are highly correlated, as expected
# > - cal_burned, steps, distance, activity_cals, mins_total_activity

# %%
def time_series_graphs(df): 
    for col in df.columns:
        plt.plot(df[col])
        plt.title(col)
        plt.show()

# %%
f, (ax1, ax2) = plt.subplots(1, 2, sharey=True, figsize=(14,4))
ax1.plot(df.cal_burned.resample("D").mean())
ax2.plot(df.cal_burned.resample("W").mean())
f.suptitle("cals_burned")
f.show()

# %%
plt.plot(df.cal_burned.resample("D").mean())
plt.plot(df.cal_burned.resample("W").mean(), linewidth=3, c="red")
plt.plot(df.cal_burned.resample("2W").mean(), linewidth=2, c="black")
plt.plot(df.cal_burned.resample("M").mean(), linewidth=3, c="green")

plt.show()

# %%
explore.time_series_graphs(df.resample("D").mean())

# %% [markdown]
# > - calories burned, steps, distance, floors and activity all increase over time
# >- sedetary activity decrease over time
#
#     > This person is getting more active as time increases

# %%
df.sort_values(by="cal_burned").head()
# Out:
#             cal_burned  steps  distance  floors  mins_sedentary  \
# date
# 2018-08-26       799.0  207.0       0.1     1.0            28.0
# 2018-06-26      2144.0    0.0       0.0     0.0          1440.0
# 2018-07-06      2144.0    0.0       0.0     0.0          1440.0
# 2018-07-03      2144.0    0.0       0.0     0.0          1440.0
# 2018-06-28      2145.0    0.0       0.0     0.0          1440.0
#
#             mins_light_activity  mins_fair_activity  mins_very_active  \
# date
# 2018-08-26                 13.0                 0.0               0.0
# 2018-06-26                  0.0                 0.0               0.0
# 2018-07-06                  0.0                 0.0               0.0
# 2018-07-03                  0.0                 0.0               0.0
# 2018-06-28                  0.0                 0.0               0.0
#
#             activity_cals  mins_total_activity    day
# date
# 2018-08-26           51.0                 13.0  0-Sun
# 2018-06-26            0.0                  0.0  2-Tue
# 2018-07-06            0.0                  0.0  5-Fri
# 2018-07-03            0.0                  0.0  2-Tue
# 2018-06-28            0.0                  0.0  4-Thu

# %% [markdown]
# Found an outlier in row "2018-08-26". It is seen that the calories burned are much lower than the metabolic rate given when the person records no movement at all. Utilized the `fix_outliers` function to replace the 799 calories with 2144 calories. Also replaced the 28 mins of sedentary to 1427 minutes. This is the total minutes (1440) subtracted by the mins of total activity (13) of that day.

# %%
df = prepare.fix_outliers(df)

# %% [markdown]
# ### Investigate BMR

# %%
# df[["cal_burned","activity_cals"]].plot(figsize=(12,6))

df.cal_burned.plot(figsize=(12,6))
df.activity_cals.plot()
df.cal_burned.resample("W").mean().plot(linewidth=3)
df.activity_cals.resample("W").mean().plot(linewidth=3)

plt.show()

# %% [markdown]
# > It is seen that the calories burned and the activity calories follow the same path. It is determined that this is due to the person's Basal Metabolic Rate (BMR), which puts the calories burned on a pedastal.

# %% [markdown]
# Finding the average calories when the person does not take any steps and has a whole day of sedentary time.

# %%
df [(df.steps == 0) & (df.mins_sedentary == 1440)].cal_burned.mean()
# Out:
# 2144.8888888888887

# %% [markdown]
# It is hypothesized that when the active calories are subtracted from the total calories, the difference will be the BMR of 2145.

# %%
(df.cal_burned - df.activity_cals).mean()
# Out:
# 1923.3422222222223

# %%
(df.cal_burned - df.activity_cals).plot()
plt.show()

# %% [markdown]
# > The BMR is not constant and is decreasing over time. It implies that the person is decreasing their weight.

# %% [markdown]
# ### Determine Height

# %% [markdown]
# ### Trends by Day

# %%
for col in df.select_dtypes(np.number):
    df[col].groupby(df.day).sum().plot.bar()
    plt.title("{} by day of the week".format(col))
    plt.show()

# %% [markdown]
# > The highest activity is seen on the weekends. Perhaps they have a desk job and leave their errands for Sundays. However the floors increase drastically on Sundays. Perhaps that is their long walk day.

# %% [markdown]
# ## VII. Split

# %% [markdown]
# Split our data using a cutoff date that is two weeks long

# %%
df.tail()
# Out:
#             cal_burned    steps  distance  floors  mins_sedentary  \
# date
# 2018-12-02      3957.0  13257.0      6.23   195.0           725.0
# 2018-12-03      3660.0  12915.0      6.12     6.0           782.0
# 2018-12-04      3384.0  13763.0      6.49    13.0           608.0
# 2018-12-05      3670.0  13865.0      6.52    12.0           739.0
# 2018-12-06      3669.0  14774.0      6.96     9.0           647.0
#
#             mins_light_activity  mins_fair_activity  mins_very_active  \
# date
# 2018-12-02                265.0                13.0              70.0
# 2018-12-03                219.0                40.0              51.0
# 2018-12-04                199.0                11.0              67.0
# 2018-12-05                200.0                12.0              69.0
# 2018-12-06                198.0                 4.0              78.0
#
#             activity_cals  mins_total_activity    day
# date
# 2018-12-02         2305.0                348.0  0-Sun
# 2018-12-03         1993.0                310.0  1-Mon
# 2018-12-04         1663.0                277.0  2-Tue
# 2018-12-05         1968.0                281.0  3-Wed
# 2018-12-06         1962.0                280.0  4-Thu

# %%
df1 = df.resample("2W").mean()

# %%
def split_one_week(df):
    train = df[:'2018-11-25'].resample("W").agg("mean")
    test = df['2018-12-02':].resample("W").agg("mean")
    return train, test

def split_two_week(df):
    train = df1[:'2018-11-25']
    test = df1['2018-12-09':]
    return train, test

# %%
train, test = split_one_week(df)

# %%
train.tail()
# Out:
#              cal_burned         steps  distance     floors  mins_sedentary  \
# date
# 2018-10-28  3608.000000  12850.142857  6.060000  14.142857      691.142857
# 2018-11-04  3944.428571  16011.142857  7.552857  11.285714      635.428571
# 2018-11-11  3985.857143  15010.857143  7.182857  31.142857      625.714286
# 2018-11-18  3814.571429  14095.000000  6.708571  18.142857      605.000000
# 2018-11-25  3760.428571  12690.142857  6.117143  37.285714      603.142857
#
#             mins_light_activity  mins_fair_activity  mins_very_active  \
# date
# 2018-10-28           194.714286           19.571429         62.714286
# 2018-11-04           210.285714           23.714286         85.857143
# 2018-11-11           199.714286           17.285714         89.285714
# 2018-11-18           251.000000           25.285714         61.857143
# 2018-11-25           261.428571           15.857143         57.857143
#
#             activity_cals  mins_total_activity
# date
# 2018-10-28    1815.857143           277.000000
# 2018-11-04    2204.571429           319.857143
# 2018-11-11    2239.714286           306.285714
# 2018-11-18    2139.571429           338.142857
# 2018-11-25    2092.000000           335.142857

# %%
test.head()
# Out:
#             cal_burned     steps  distance  floors  mins_sedentary  \
# date
# 2018-12-02     3957.00  13257.00    6.2300   195.0           725.0
# 2018-12-09     3595.75  13829.25    6.5225    10.0           694.0
#
#             mins_light_activity  mins_fair_activity  mins_very_active  \
# date
# 2018-12-02                265.0               13.00             70.00
# 2018-12-09                204.0               16.75             66.25
#
#             activity_cals  mins_total_activity
# date
# 2018-12-02         2305.0                348.0
# 2018-12-09         1896.5                287.0

# %%
# train, test = split.split_two_weeks(df,'D')

# %%
print('Observations: %d' % (len(train.values) + len(test.values)))
print('Training Observations: %d' % (len(train)))
print('Testing Observations: %d' % (len(test)))
# Out:
# Observations: 33
# Training Observations: 31
# Testing Observations: 2

# %% [markdown]
# Every feature is plotted with their train and test split.

# %%
for col in train.columns: 
    plt.figure(figsize=(8, 4))
    train[col].plot()
    test[col].plot()
    plt.title("{}".format(col))
    plt.show()

# %% [markdown]
# ## VIII. Model

# %% [markdown]
# Will test out different models on the data:
# - last_value: predicts based on the last value of the dataframe
# - simple_avg: predicts based on the average of the whole dataframe
# - moving_avg: predicts based on an average of a specified time (30 days in this case)
# - holt: predicts based on adding a second exponential smoothing model

# %% [markdown]
# ### Resampling by day

# %%
for col in train.columns:
    print(col)
    print(model.run_models(train[col], test[col]))
    print()
# Out:
# cal_burned
#    model_type            mse        rmse
# 0  last_value  983262.214286  991.595792
# 1  simple_avg  118407.765823  344.104295
# 2  moving_avg  204561.102063  452.284316
# 3        holt  402940.015638  634.775563
#
# steps
#    model_type           mse         rmse
# 0  last_value  2.849573e+07  5338.138781
# 1  simple_avg  2.264120e+07  4758.276728
# 2  moving_avg  1.341157e+07  3662.180963
# 3        holt  1.964230e+07  4431.963701
#
# distance
#    model_type       mse      rmse
# 0  last_value  5.859221  2.420583
# 1  simple_avg  6.330626  2.516073
# 2  moving_avg  3.137327  1.771250
# 3        holt  4.297116  2.072949
#
# floors
#    model_type           mse        rmse
# 0  last_value  24951.642857  157.960890
# 1  simple_avg   2426.347334   49.257967
# 2  moving_avg   2220.363016   47.120728
# 3        holt   2210.726439   47.018363
#
# mins_sedentary
#    model_type           mse        rmse
# 0  last_value  23895.714286  154.582387
# 1  simple_avg  34052.690785  184.533712
# 2  moving_avg   6314.474921   79.463670
# 3        holt  11828.253481  108.757774
#
# mins_light_activity
#    model_type          mse       rmse
# 0  last_value  3403.071429  58.335850
# 1  simple_avg  3707.924920  60.892733
# 2  moving_avg  1225.565397  35.008076
# 3        holt  3274.354242  57.221973
#
# mins_fair_activity
#    model_type         mse       rmse
# 0  last_value  110.714286  10.522086
# 1  simple_avg   93.170029   9.652462
# 2  moving_avg  158.263968  12.580301
# 3        holt  137.295690  11.717324
#
# mins_very_active
#    model_type          mse       rmse
# 0  last_value  5184.071429  72.000496
# 1  simple_avg  1242.973776  35.255833
# 2  moving_avg  1565.056825  39.560799
# 3        holt  1875.974828  43.312525
#
# activity_cals
#    model_type           mse         rmse
# 0  last_value  1.130008e+06  1063.018109
# 1  simple_avg  2.637829e+05   513.598004
# 2  moving_avg  2.013535e+05   448.724252
# 3        holt  5.030470e+05   709.258043
#
# mins_total_activity
#    model_type           mse        rmse
# 0  last_value  14384.285714  119.934506
# 1  simple_avg   5042.992841   71.014033
# 2  moving_avg   1081.543968   32.886836
# 3        holt   7817.869176   88.418715

# %% [markdown]
# ### Resampling by One Week

# %%
for col in train.columns:
    print(col)
    print(model.run_models(train[col], test[col]))
    print()
# Out:
# cal_burned
#    model_type            mse        rmse
# 0  last_value   32879.679209  181.327547
# 1  simple_avg  177536.741142  421.351090
# 2  moving_avg  170834.959912  413.321860
# 3        holt   47386.319390  217.683990
#
# steps
#    model_type           mse         rmse
# 0  last_value  8.094461e+05   899.692198
# 1  simple_avg  2.774257e+07  5267.121198
# 2  moving_avg  2.643710e+07  5141.701827
# 3        holt  3.309228e+05   575.258909
#
# distance
#    model_type       mse      rmse
# 0  last_value  0.088526  0.297532
# 1  simple_avg  6.052459  2.460175
# 2  moving_avg  5.762490  2.400519
# 3        holt  0.157486  0.396845
#
# floors
#    model_type           mse        rmse
# 0  last_value  12809.153061  113.177529
# 1  simple_avg  16805.618973  129.636488
# 2  moving_avg  16769.787959  129.498216
# 3        holt  14236.023011  119.314806
#
# mins_sedentary
#    model_type           mse        rmse
# 0  last_value  11552.091837  107.480658
# 1  simple_avg  13785.133625  117.410109
# 2  moving_avg  12287.925737  110.850917
# 3        holt  14607.978365  120.863470
#
# mins_light_activity
#    model_type          mse       rmse
# 0  last_value  1655.397959  40.686582
# 1  simple_avg  3329.782482  57.704267
# 2  moving_avg  3206.448662  56.625512
# 3        holt  1025.881057  32.029378
#
# mins_fair_activity
#    model_type        mse      rmse
# 0  last_value   4.480230  2.116655
# 1  simple_avg   3.533639  1.879798
# 2  moving_avg   3.520230  1.876227
# 3        holt  25.700371  5.069553
#
# mins_very_active
#    model_type          mse       rmse
# 0  last_value   108.944515  10.437649
# 1  simple_avg  1269.866886  35.635192
# 2  moving_avg  1210.002769  34.785094
# 3        holt     8.607344   2.933828
#
# activity_cals
#    model_type            mse        rmse
# 0  last_value   41794.625000  204.437338
# 1  simple_avg  454644.234803  674.273116
# 2  moving_avg  435710.407404  660.083637
# 3        holt   53177.923928  230.603391
#
# mins_total_activity
#    model_type          mse       rmse
# 0  last_value  1241.520408  35.235215
# 1  simple_avg  8059.795490  89.776364
# 2  moving_avg  7716.086757  87.841259
# 3        holt  1181.992424  34.380117

# %% [markdown]
# ### Resampling by Two Weeks

# %%
for col in train.columns:
    print(col)
    print(model.run_models(train[col], test[col]))
    print()
# Out:
# cal_burned
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-101-395f57611b0c> in <module>
#       1 for col in train.columns:
#       2     print(col)
# ----> 3     print(model.run_models(train[col], test[col]))
#       4     print()
#
# ~/codeup-data-science/fit_bit_project/model.py in run_models(train, test)
#      99     model_strength = model_strength.append(row, ignore_index= True)
#     100
# --> 101     row,_ = moving_avg(train,test)
#     102     model_strength = model_strength.append(row, ignore_index= True)
#     103
#
# ~/codeup-data-science/fit_bit_project/model.py in moving_avg(train, test)
#      40     moving_average = train.rolling(30).mean()[-1]
#      41     yhat = [moving_average] * test.shape[0]
# ---> 42     mse = mean_squared_error(test, yhat)
#      43     rmse = mse**.5
#      44     return {'model_type': 'moving_avg',
#
# /usr/local/anaconda3/lib/python3.7/site-packages/sklearn/metrics/regression.py in mean_squared_error(y_true, y_pred, sample_weight, multioutput)
#     239     """
#     240     y_type, y_true, y_pred, multioutput = _check_reg_targets(
# --> 241         y_true, y_pred, multioutput)
#     242     check_consistent_length(y_true, y_pred, sample_weight)
#     243     output_errors = np.average((y_true - y_pred) ** 2, axis=0,
#
# /usr/local/anaconda3/lib/python3.7/site-packages/sklearn/metrics/regression.py in _check_reg_targets(y_true, y_pred, multioutput)
#      77     check_consistent_length(y_true, y_pred)
#      78     y_true = check_array(y_true, ensure_2d=False)
# ---> 79     y_pred = check_array(y_pred, ensure_2d=False)
#      80
#      81     if y_true.ndim == 1:
#
# /usr/local/anaconda3/lib/python3.7/site-packages/sklearn/utils/validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, warn_on_dtype, estimator)
#     540         if force_all_finite:
#     541             _assert_all_finite(array,
# --> 542                                allow_nan=force_all_finite == 'allow-nan')
#     543
#     544     if ensure_min_samples > 0:
#
# /usr/local/anaconda3/lib/python3.7/site-packages/sklearn/utils/validation.py in _assert_all_finite(X, allow_nan)
#      54                 not allow_nan and not np.isfinite(X).all()):
#      55             type_err = 'infinity' if allow_nan else 'NaN, infinity'
# ---> 56             raise ValueError(msg_err.format(type_err, X.dtype))
#      57     # for object dtype data, we only check for NaNs (GH-13254)
#      58     elif X.dtype == np.dtype('object') and not allow_nan:
#
# ValueError: Input contains NaN, infinity or a value too large for dtype('float64').

# %% [markdown]
#     > It is determined that the moving average model performs the best overall.

# %% [markdown]
# ## IX. Findings

# %% [markdown]
# - the user of the fitbit is about 6 feet tall
# - based on the height, it is most likely that the user is a man
# -
#
# - the user is losing weight over time, based on basal metabolic rate (BMR)
